# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rovnez/fc-26-fifa-26-player-data")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'fc-26-fifa-26-player-data' dataset.
# Path to dataset files: /kaggle/input/fc-26-fifa-26-player-data

# %%
df = pd.read_csv(f"{path}/FC26_20250921.csv")
# Out:
# /tmp/ipython-input-3548085166.py:1: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{path}/FC26_20250921.csv")

# %%
df.head()
# Out:
#    player_id                                player_url  fifa_version  \
# 0     252371    /player/252371/jude-bellingham/260004/            26
# 1     239053  /player/239053/federico-valverde/260004/            26
# 2     212622     /player/212622/joshua-kimmich/260004/            26
# 3     235212      /player/235212/achraf-hakimi/260004/            26
# 4     224232     /player/224232/nicolo-barella/260004/            26
#
#    fifa_update fifa_update_date     short_name  \
# 0            4       2025-09-19  J. Bellingham
# 1            4       2025-09-19    F. Valverde
# 2            4       2025-09-19     J. Kimmich
# 3            4       2025-09-19      A. Hakimi
# 4            4       2025-09-19     N. Barella
#
#                             long_name player_positions  overall  potential  \
# 0      Jude Victor William Bellingham          CAM, CM       90         94
# 1  Federico Santiago Valverde Dipetta      CM, CDM, RB       89         90
# ...

# %%
df.columns
# Out:
# Index(['player_id', 'player_url', 'fifa_version', 'fifa_update',
#        'fifa_update_date', 'short_name', 'long_name', 'player_positions',
#        'overall', 'potential',
#        ...
#        'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk',
#        'player_face_url'],
#       dtype='object', length=110)

# %%
# There are lots of unnecessary pieces of information. We should select columns we need.

# %%
card_columns = ["long_name", "overall", "pace", "shooting", "passing", "dribbling","defending", "physic", "preferred_foot"]

# %%
df_card = df[card_columns]

# %%
df_card.head()
# Out:
#                             long_name  overall  pace  shooting  passing  \
# 0      Jude Victor William Bellingham       90  80.0      86.0     83.0
# 1  Federico Santiago Valverde Dipetta       89  88.0      84.0     84.0
# 2               Joshua Walter Kimmich       89  72.0      74.0     89.0
# 3        Achraf Hakimi Mouhأشرف حكيمي       89  92.0      79.0     82.0
# 4                      Nicolò Barella       87  80.0      78.0     84.0
#
#    dribbling  defending  physic preferred_foot
# 0       90.0       78.0    85.0          Right
# 1       84.0       83.0    85.0          Right
# 2       84.0       83.0    79.0          Right
# 3       83.0       82.0    79.0          Right
# 4       86.0       81.0    76.0          Right

# %%
df_card.isnull().sum()
# Out:
# long_name       0
# overall         0
# pace         2062
# shooting     2062
# passing      2062
# dribbling    2062
# defending    2062
# physic       2062
# dtype: int64

# %%
df.shape
# Out:
# (18405, 110)

# %%
df_card.dropna(axis=0, inplace=True)
# Out:
# /tmp/ipython-input-3018890873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_card.dropna(axis=0, inplace=True)

# %%
df_card.shape
# Out:
# (16343, 8)

# %%
df_card.head()
# Out:
#                             long_name  overall  pace  shooting  passing  \
# 0      Jude Victor William Bellingham       90  80.0      86.0     83.0
# 1  Federico Santiago Valverde Dipetta       89  88.0      84.0     84.0
# 2               Joshua Walter Kimmich       89  72.0      74.0     89.0
# 3        Achraf Hakimi Mouhأشرف حكيمي       89  92.0      79.0     82.0
# 4                      Nicolò Barella       87  80.0      78.0     84.0
#
#    dribbling  defending  physic preferred_foot
# 0       90.0       78.0    85.0          Right
# 1       84.0       83.0    85.0          Right
# 2       84.0       83.0    79.0          Right
# 3       83.0       82.0    79.0          Right
# 4       86.0       81.0    76.0          Right

# %%
# no need name for model training
df_card = df_card.drop("long_name", axis=1)

# %%
sns.pairplot(df_card)
plt.show()

# %%
X = df_card.drop("overall", axis=1)
y = df_card["overall"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.metrics import r2_score

# %%
models = {
    "Linear Regression" : LinearRegression(),
    "K Neighbors Regressor" : KNeighborsRegressor(),
    "Supoort Vector Regressor" : SVR(),
    "Decision Tree" : DecisionTreeRegressor(),
    "Random Forest Regressor" : RandomForestRegressor(),
    "Adaboost Regressor" : AdaBoostRegressor(),
    "Gradient Boost Regressor" : GradientBoostingRegressor(),
    "XGBoost Regressor" : XGBRegressor(),
    "LXBoost Regressor" : LGBMRegressor()
}

# %%
def evaluate_model(true, predict):
  r2score = r2_score(true, predict)
  return r2score

# %%
for i in range(len(list(models))):
  model = list(models.values())[i]
  model.fit(X_train_scaled, y_train)

  y_prediction = model.predict(X_test_scaled)

  r2_score_ = evaluate_model(y_test, predict=y_prediction)

  print(list(models.keys())[i])
  print("Model Performance")
  print("R2 Score : ", r2_score_)
  print("**********************\n\n")
# Out:
# Linear Regression
# Model Performance
# R2 Score :  0.7763891334177275
# **********************
#
#
# K Neighbors Regressor
# Model Performance
# R2 Score :  0.9437121661520067
# **********************
#
#
# Supoort Vector Regressor
# Model Performance
# R2 Score :  0.9657533944510148
# **********************
#
#
# Decision Tree
# Model Performance
# R2 Score :  0.9308477676786646
# **********************
#
#
# Random Forest Regressor
# Model Performance
# R2 Score :  0.9653951774417834
# **********************
#
#
# Adaboost Regressor
# Model Performance
# R2 Score :  0.9127551833826708
# **********************
#
#
# Gradient Boost Regressor
# Model Performance
# R2 Score :  0.9600128322757288
# **********************
#
#
# XGBoost Regressor
# Model Performance
# R2 Score :  0.9661067724227905
# **********************
#
#
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001184 seconds.
# ...

# %%
best_model = LGBMRegressor()

# %%
best_model.fit(X_train_scaled, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001159 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 397
# [LightGBM] [Info] Number of data points in the train set: 11440, number of used features: 6
# [LightGBM] [Info] Start training from score 65.956643
# LGBMRegressor()

# %%
with open("/content/drive/MyDrive/model_savings_new.pkl", "wb") as f:
  pickle.dump({
      "model" : best_model,
      "scaler" : scaler
  }, f)
